# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including NLTK and spaCy.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 3.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.3/12.8 MB 2.4 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.8/12.8 MB 2.6 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/12.8 MB 2.5 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/12.8 MB 2.7 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.7/12.8 MB 2.7 MB/s eta 0:00:04
#      ------------- -------------------------- 4.2/12.8 MB 2.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.8 MB 2.8 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.8 MB 2.8 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.8 MB 2.8 MB/s eta 0:00:03
# ...

# %%
# Import Required Libraries
# %pip install -U spacy
# %pip install en_core_web_sm

import nltk
import spacy

# Download necessary NLTK data files
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# Load spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Load Text Data
# Load or define the text data that will be used for POS tagging.

# %%
# Load Text Data

# Define the text data
text_data = """
Natural language processing (NLP) is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language.
The ultimate goal of NLP is to enable computers to understand, interpret, and generate human languages in a way that is both meaningful and useful.
"""

# Tokenize the text data using NLTK
nltk_tokens = nltk.word_tokenize(text_data)

# Tokenize the text data using spaCy
spacy_doc = nlp(text_data)
spacy_tokens = [token.text for token in spacy_doc]

# Display the tokens
print("NLTK Tokens:", nltk_tokens)
print("spaCy Tokens:", spacy_tokens)
# Out:
# NLTK Tokens: ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'languages', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.']
# spaCy Tokens: ['\n', 'Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', '\n', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'languages', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.', '\n']

# %%
# Define the text data
text_data ="omar hamed eats food and drinks water"

# Tokenize the text data using NLTK
nltk_tokens = nltk.word_tokenize(text_data)

# Tokenize the text data using spaCy
spacy_doc = nlp(text_data)
spacy_tokens = [token.text for token in spacy_doc]

# Display the tokens
print("NLTK Tokens:", nltk_tokens)
print("spaCy Tokens:", spacy_tokens)

# Perform POS tagging using NLTK
nltk_pos_tags = nltk.pos_tag(nltk_tokens)

# Perform POS tagging using spaCy
spacy_pos_tags = [(token.text, token.pos_) for token in spacy_doc]

# Display the POS tags
print("NLTK POS Tags:", nltk_pos_tags)
print("spaCy POS Tags:", spacy_pos_tags)
# Out:
# NLTK Tokens: ['omar', 'hamed', 'eats', 'food', 'and', 'drinks', 'water']
# spaCy Tokens: ['omar', 'hamed', 'eats', 'food', 'and', 'drinks', 'water']
# NLTK POS Tags: [('omar', 'NN'), ('hamed', 'VBD'), ('eats', 'NNS'), ('food', 'NN'), ('and', 'CC'), ('drinks', 'NNS'), ('water', 'NN')]
# spaCy POS Tags: [('omar', 'PROPN'), ('hamed', 'VERB'), ('eats', 'VERB'), ('food', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('water', 'NOUN')]

# %% [markdown]
# # Tokenize Text
# Use NLTK or spaCy to tokenize the text into words.

# %%
# Tokenize Text

# Tokenize the text data using NLTK
nltk_tokens = nltk.word_tokenize(text_data)

# Tokenize the text data using spaCy
spacy_doc = nlp(text_data)
spacy_tokens = [token.text for token in spacy_doc]

# Display the tokens
print("NLTK Tokens:", nltk_tokens)
print("spaCy Tokens:", spacy_tokens)
# Out:
# NLTK Tokens: ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'languages', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.']
# spaCy Tokens: ['\n', 'Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', '\n', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'languages', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.', '\n']

# %% [markdown]
# # POS Tagging
# Use NLTK or spaCy to perform POS tagging on the tokenized text.

# %%
# POS Tagging

# Perform POS tagging using NLTK
nltk_pos_tags = nltk.pos_tag(nltk_tokens)

# Perform POS tagging using spaCy
spacy_pos_tags = [(token.text, token.pos_) for token in spacy_doc]

# Display the POS tags
print("NLTK POS Tags:", nltk_pos_tags)
print("spaCy POS Tags:", spacy_pos_tags)
# Out:
# NLTK POS Tags: [('Natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('field', 'NN'), ('of', 'IN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('that', 'WDT'), ('focuses', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('interaction', 'NN'), ('between', 'IN'), ('computers', 'NNS'), ('and', 'CC'), ('humans', 'NNS'), ('through', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('.', '.'), ('The', 'DT'), ('ultimate', 'JJ'), ('goal', 'NN'), ('of', 'IN'), ('NLP', 'NNP'), ('is', 'VBZ'), ('to', 'TO'), ('enable', 'JJ'), ('computers', 'NNS'), ('to', 'TO'), ('understand', 'VB'), (',', ','), ('interpret', 'VB'), (',', ','), ('and', 'CC'), ('generate', 'VB'), ('human', 'JJ'), ('languages', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('way', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('both', 'DT'), ('meaningful', 'JJ'), ('and', 'CC'), ('useful', 'JJ'), ('.', '.')]
# ...

# %%
import pandas as pd
df=pd.DataFrame(nltk_pos_tags, columns=['Word', 'POS'])
for token in spacy_doc:
    df.loc[df['Word']==token.text, 'POS_spacy']=token.pos_
    # print(token.text,"|", token.pos_,spacy.explain(token.pos), "|", token.tag_, "|", token.dep_, "|", token.shape_, "|", token.is_alpha, "|", token.is_stop)
df
# Out:
#             Word  POS POS_spacy
# 0        Natural   JJ       ADJ
# 1       language   NN      NOUN
# 2     processing   NN      NOUN
# 3              (    (     PUNCT
# 4            NLP  NNP     PROPN
# 5              )    )     PUNCT
# 6             is  VBZ       AUX
# 7              a   DT       DET
# 8          field   NN      NOUN
# 9             of   IN       ADP
# 10    artificial   JJ       ADJ
# 11  intelligence   NN      NOUN
# 12          that  WDT      PRON
# 13       focuses  VBZ      VERB
# 14            on   IN       ADP
# 15           the   DT       DET
# 16   interaction   NN      NOUN
# 17       between   IN       ADP
# 18     computers  NNS      NOUN
# 19           and   CC     CCONJ
# 20        humans  NNS      NOUN
# 21       through   IN       ADP
# 22       natural   JJ       ADJ
# 23      language   NN      NOUN
# 24             .    .     PUNCT
# 25           The   DT       DET
# 26      ultimate   JJ       ADJ
# 27          goal   NN      NOUN
# ...

# %% [markdown]
# # Visualize POS Tags
# Visualize the POS tags using a library like matplotlib or seaborn.

# %%
# Visualize POS Tags

import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Extract POS tags from NLTK and spaCy results
nltk_pos = [tag for word, tag in nltk_pos_tags]
spacy_pos = [tag for word, tag in spacy_pos_tags]

# Count the frequency of each POS tag
nltk_pos_counts = Counter(nltk_pos)
spacy_pos_counts = Counter(spacy_pos)

# Create a DataFrame for visualization
import pandas as pd

nltk_pos_df = pd.DataFrame(nltk_pos_counts.items(), columns=['POS', 'Count'])
spacy_pos_df = pd.DataFrame(spacy_pos_counts.items(), columns=['POS', 'Count'])

# Plot the POS tag frequencies using seaborn
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.barplot(x='POS', y='Count', data=nltk_pos_df,palette='viridis')
plt.title('NLTK POS Tag Frequency')
plt.xticks(rotation=90)

plt.subplot(1, 2, 2)
sns.barplot(x='POS', y='Count', data=spacy_pos_df, palette='inferno')
plt.title('spaCy POS Tag Frequency')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Omar\AppData\Local\Temp\ipykernel_19716\3079813947.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='POS', y='Count', data=nltk_pos_df,palette='viridis')
# C:\Users\Omar\AppData\Local\Temp\ipykernel_19716\3079813947.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='POS', y='Count', data=spacy_pos_df, palette='inferno')
